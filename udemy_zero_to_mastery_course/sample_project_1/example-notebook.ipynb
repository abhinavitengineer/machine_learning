# %% [markdown]
# ### This is a reference notebook that one can follow for building their ML-DataScience related projects and follow below framework.
#
# This framework helps in provding structural appraoch and helps in breaking the projects in different sections. Each section will focus on their respective scope which provides cleaner, easy to understand approach in building project.

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# ## Problem Definition
#
# Predict heart disease.

# %% [markdown]
# ## Data
#
# This is the data we are using
